# %%
import pandas as pd  # таблицы
import requests as rq  # запросы сети
import re # регулярные выражения
from bs4 import BeautifulSoup  # парсинг
from fake_useragent import UserAgent  # эмуляция браузера

# обработка временной зоны
import pytz
import datetime

dir = "D:\HSE\Pump_Dump\TG\\"  # папка проекта

# %%
# получение "сырых" данных с диска по каналам
def channel_raw_data(channel):
    # формируем путь к файлу с данными канала
    channel_path = dir + channel + ".csv"
    # считываем существующие данные, если канал есть, если нет создаем файл
    try:
        # загрузка файла
        df = pd.read_csv(channel_path, encoding="utf-8", sep="|", keep_default_na=False)
    except:
        cols = {
            "CHANNEL": [],
            "POST": [],
            "NEWS_DATE": [],
            "NEWS_TIME": [],
            "NEWS_TEXT": [],
        }
        df = pd.DataFrame(cols)
        df.to_csv(
            channel_path,
            index=False,
            encoding="utf-8",
            sep="|",
        )
    return df

# %%
# описание канала
def channel_info(channel):
    # главная страница канала
    page = rq.get(
        "https://t.me/s/" + channel, headers={"User-Agent": UserAgent().chrome}
    )
    raw_text = BeautifulSoup(page.text.replace("<br/>", " "), features="html.parser")
    # получаем номер крайней новости и количество подписчиков
    to_number = int(str(raw_text.find_all("link")[1].get("href")).split("=")[1])
    channel_counter = raw_text.find(
        "div", attrs={"class": "tgme_header_counter"}
    ).text.split(" ")[0]
    return (to_number, channel_counter)

# %%
# загрузка конкретной новости
def load_post(channel, post):
    # переменные для загрузки
    news_date = ""
    news_time = ""
    news_text = ""
    try:
        # обращаемся к странице
        page_link = "https://t.me/" + channel + "/" + str(post) + "?embed=1"
        page = rq.get(page_link)
        # загружаем ее в парсер и сразу удаляем переносы строки, которые встречаются в тексте страницы
        raw_text = BeautifulSoup(page.text.replace("<br/>", " "), features="html.parser")
        # дата и время новости c учетом временной зоны # Europe / Moscow (+3)
        news_date = raw_text.find("time").attrs["datetime"]
        news_date = datetime.datetime.strptime(news_date, "%Y-%m-%dT%H:%M:%S%z")
        tz = pytz.timezone("Etc/GMT-3")
        news_date = tz.normalize(news_date.astimezone(tz))
        news_time = news_date.strftime("%H:%M")
        news_date = news_date.strftime("%d-%m-%Y")
        # текст новости
        news_text = raw_text.find(
            "div", attrs={"class": "tgme_widget_message_text js-message_text"}
        ).text
        # оставляем только необходимые знаки
        news_text = re.sub(r"[^0-9А-Яа-яA-Za-zёЁ-–—,.%«»:/?!$№€₽ ]", " ", news_text)
        news_text = " ".join(news_text.split())
    except:
        # если ошибка при обработке, в текст пишем об ошибке
        news_text = "error"
    data = [
        {
            "CHANNEL": channel,
            "POST": int(post),
            "NEWS_DATE": news_date,
            "NEWS_TIME": news_time,
            "NEWS_TEXT": news_text,
        }
    ]
    if news_text=="error":data="error"
    return data

# %%
channels = pd.read_csv(dir + "!channels.csv", delimiter="|")
# обрабатываем каждый канал
for channel in channels["CHANNEL"].values:
    # загружаем данные из корпуса
    channel_df = channel_raw_data(channel)
    # получаем номер крайней новости в корпусе
    from_date = channel_df["POST"].max()
    # загружаем данные о канале
    channel_data = channel_info(channel)
    # дата крайней новости на канале
    to_date = channel_data[0]
    # актуальное количество подписчиков канала
    channel_counter = channel_data[1]
    # обновляем количество подписчиков в списке каналов (RELIABILITY)
    channels.loc[channels["CHANNEL"] == channel, "RELIABILITY"] = channel_counter
    # и обновляем его в списке
    channels.to_csv(
        dir + "!channels.csv",
        index=False,
        encoding="utf-8",
        sep="|",
    )
    # если новый / пустой файл, загружаем крайние N записей
    try:
        int(from_date)
    except:
        from_date = int(to_date) - 1000
    # общая информация о предстоящей загрузке
    print(
        "Канал: ",
        channel,
        "Подписчиков: ",
        channel_counter,
        "Первая новость в корпусе: ",
        channel_df["POST"].min(),
        "Крайняя новость в корпусе: ",
        channel_df["POST"].max(),
        "Крайняя новость в ТГ: ",
        to_date,
        "Будет загружено",
        int(to_date) - int(from_date) - 1,
        sep="\n",
    )

    # в цикле проходим по всем незагруженным новостям
    # для этого создаем временный фрейм
    temp_frame = pd.DataFrame()
    #from_date = 16500  ### для разовых загрузок
    #to_date = 20895  ### для разовых загрузок
    for i in range(from_date + 1, to_date):
        # получаем словарь из данных страницы
        temp_row = load_post(channel, i)
        print(temp_row)
        # если нет ошибочной записи, то добавляем ее во временный фрейм
        if temp_row != "error":
            temp_frame = pd.concat(
                [temp_frame, pd.DataFrame.from_dict(temp_row)], ignore_index=True
            )
    # в некоторых новостях встречаются дубли текстов, удаляем их
    temp_frame.drop_duplicates(subset="NEWS_TEXT", keep="first", inplace=True)
    # добавляем новости в основной фрейм канала
    channel_df = pd.concat([channel_df, temp_frame], ignore_index=False)
    # POST должен быть числовым
    channel_df["POST"] = channel_df["POST"].astype(int)
    # перед обновлением файла сортируем по убыванию даты для удобства просмотра файла
    channel_df = channel_df.sort_values(by="POST", ascending=False)
    channel_df.to_csv(
        dir + channel + ".csv",
        index=False,
        encoding="utf-8",
        sep="|",
    )
# Out:
# Канал:
# signals_moex
# Подписчиков:
# 12.7K
# Первая новость в корпусе:
# 4401
# Крайняя новость в корпусе:
# 6067
# Крайняя новость в ТГ:
# 6072
# Будет загружено
# 4
# [{'CHANNEL': 'signals_moex', 'POST': 6068, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '11:58', 'NEWS_TEXT': 'RASP крупная заявка на покупку 2к лотов 8 528 000 руб по цене 426.40 До плотности 11 пунктов 0,129% Устанавливайте бесплатный терминал для скальпинга CScalp и следите за плотностями в режиме реального времени. Как отрабатывать такие ситуации смотрите здесь'}]
# [{'CHANNEL': 'signals_moex', 'POST': 6069, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '12:07', 'NEWS_TEXT': 'SHORT SMLT from 3 733.5 р. stop loss 3 741 р. 30m TF. Бумага находится в нисходящем тренде и сформировала наклонку из каскада уровней, жду подход к уровню 3733,5 и буду заходить в пробой, цель собрать каскад, спот исходя из вашего РМ. Бесплатный терминал для скальпинга здесь. Открыть график ПробойНаклонки'}]
# [{'CHANNEL': 'signals_moex', 'POST': 6070, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '12:59', 'NEWS_TEXT': 'LONG IRAO from 4.134 р. stop loss 4.13 р. 30m TF. Бумага в восходящем тренде и сформировала наклонку, жду подход с обязательным поджатием к уровню 4,1340 и буду заходить в пробой, стоп за локальную проторговку, когда нарисует. Цель снять каскад. Discord сервер CScalp здесь. Открыть график ПробойНаклонки'}]
# [{'CHANNEL': 'signals_moex', 'POST': 6071, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '16:15', 'NEWS_TEXT': 'NVTK крупная заявка на продажу 54к лотов 77 910 000 руб по цене 1 470.0 До плотности 9 пунктов 0,136% Устанавливайте бесплатный терминал для скальпинга CScalp и следите за плотностями в режиме реального времени. Как отрабатывать такие ситуации смотрите здесь'}]
# Канал:
# sonbuffet
# Подписчиков:
# 64.7K
# Первая новость в корпусе:
# 3903
# Крайняя новость в корпусе:
# 4819
# Крайняя новость в ТГ:
# 4820
# Будет загружено
# 0
# Канал:
# smfanton
# Подписчиков:
# 64.9K
# Первая новость в корпусе:
# 2601
# Крайняя новость в корпусе:
# 3431
# Крайняя новость в ТГ:
# 3434
# Будет загружено
# 2
# [{'CHANNEL': 'smfanton', 'POST': 3432, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:59', 'NEWS_TEXT': 'Вообще да. Но на самом деле нет. Из общения с подписчиками вижу, что нужен очередной комментарий на злобу дня. Многие брокеры начали открывать ИИС 3, соответствующие изменения в законе О рынке ценных бумаг официально вступили в силу с 1 января. \u200d Проблема в том, что прописанные в законе льготы не работают поправки в Налоговый кодекс НЕ приняты, они прошли только первое чтение в Госдуме. Очевидно, согласия по ним нет иначе приняли бы еще в декабре , и к третьему чтению мы можем увидеть уже другие условия по счету. Надеюсь, примут всё как есть, но мы этого не знаем. Сейчас ситуация следующая: Нельзя открыть прописанные в законе 3 счета, без потери льгот Нельзя применить комбинацию из льгот двух предыдущих типов — ИИС 1 и ИИС 2. И в целом, пока не увидим принятые поправки в НК, мы не можем знать точно, как будут на практике применяться льготы. Минфин призывает не волноваться: Отсутствие поправок в НК не повлияет на получение налоговых вычетов . Т.е. их якобы применят задним числом, в 2025 году за 2024 й. И действительно, если изменения предусматривают улучшение положения налогоплательщиков, то они могут иметь обратную силу. Но по состоянию на сейчас, мы по прежнему находимся в юридическом вакууме. Что делать зависит от вашей ситуации. Если в 2023 году у вас не было никакого ИИС стоит открыть, чтобы начал капать 5 летний срок пополнить можно потом . Если есть действующий ИИС 1 или ИИС 2 лучше пока не трансформировать в ИИС 3. Я свой старый счет второго типа буду держать, сколько позволят. Остаётся надеяться, что Минфин и депутаты сделают то, что обещали как можно быстрее примут поправки в текущем виде. А лучше с учетом наших чаяний, например, с возможностью выводить дивы и купоны на банковский счет. иис налоги льготы'}]
# [{'CHANNEL': 'smfanton', 'POST': 3433, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '11:54', 'NEWS_TEXT': 'Евротранс будет больше инвестировать в зарядную инфраструктуру В интервью Ведомостям генеральный директор компании рассказал о планах ввести до конца 2024 года не менее 35 быстрых ЭЗС с циклом зарядки 20 мин. , на каждой из которых будет как минимум 4 зарядных устройства, а на ведущих станциях 6 7. В компании отмечают растущий спрос со стороны клиентов в Московском регионе. Говорят, на зарядках возникают очереди по 3 4 электромобиля. Чтобы подстраховаться от энергетических перебоев такое редко, но все же случается , разработан проект дополнительной ветрогенерации для всех объектов, он тоже будет реализован в 2024 году. Для столь масштабной программы нужны инвестиции, о чем было бы интересно знать держателям облигаций и миноритарным акционерам. Вот как руководство комментирует решение этой задачи. Средств, привлеченных на IPO и от выпусков облигаций, достаточно для выполнения всей инвестпрограммы 2024 2025 гг. Но пока эмитент расходовал их в основном на масштабирование текущих направлений. Компания рассматривает возможность выпустить зеленые облигации, это покроет 20 25% всех расходов. Уже поданы заявки в ЦБ и на Мосбиржу, получено предварительное заключение от АКРА. Важно: допэмиссии акций 2024 2025 гг. не планируется. К 2025 году есть планы листинга акций на одной из площадок в дружественных странах. Итак, компанией сделана ставка на ускоренный рост сети зарядных станций для электромобилей. Очевидно, спрос на них будет расти, особенно в регионе присутствия АЗК ТРАССА Москва и МО. EUTR инвестиции электромобили'}]
# Канал:
# investoksana
# Подписчиков:
# 57.5K
# Первая новость в корпусе:
# 4001
# Крайняя новость в корпусе:
# 5845
# Крайняя новость в ТГ:
# 5853
# Будет загружено
# 7
# [{'CHANNEL': 'investoksana', 'POST': 5846, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '08:09', 'NEWS_TEXT': 'Утром на рынке нейтральный внешний фон. Нефть выросла до 78,7$. Доллар торгуется по 91₽. Житель Волгоградской области за один раз купил 70 тысяч литров молока на 2,2 млн рублей. В китайских акциях продолжается отскок после вчерашних интервенций властей. «Газпром» в январе нарастил поставки газа в Европу в 1,4 раза. Власти потребуют от банков отчитываться о всех операциях с бриллиантами. Китайский банк Chouzhou Commercial сообщил клиентам об остановке операций с Россией. Mash: шоколад в России скоро подорожает на 30%. Ремонт аэропортов предложили финансировать новым сбором с авиакомпаний. Экономист Беляев: самыми эффективными сейчас являются банковские вклады. Прокуратура арестовала часть имущества компании Южуралзолото. Минфин с 7 февраля вернется к покупкам валюты по бюджетному правилу, направив на этo 73.2 млрд руб., по 3.7 млрд руб. в день.'}]
# [{'CHANNEL': 'investoksana', 'POST': 5847, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '10:26', 'NEWS_TEXT': '\u200b\u200b НОВОЕ ВИДЕО УЖЕ НА ЮТУБЕ!'}]
# [{'CHANNEL': 'investoksana', 'POST': 5848, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '11:54', 'NEWS_TEXT': 'А так ли выгодны окажутся проценты по вкладам, если бакс полетит на 120 в этом году? Совсем не выгодны! Но краткосрочные Вклады и накопительные счета в рамках диверсификации всё равно пока актуальны. Вариантов ликвидно вложить деньги мало.'}]
# [{'CHANNEL': 'investoksana', 'POST': 5849, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '13:30', 'NEWS_TEXT': 'Совет Федерации одобрил закон об освобождении от налогов заблокированных средств участников ПИФ. P.S. А с моих дивидендов, которые мне возвращают с заблокированных бумаг никто налог отменять не собирается'}]
# [{'CHANNEL': 'investoksana', 'POST': 5850, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '15:14', 'NEWS_TEXT': 'Брокеры сообщили клиентам о неработающих льготах по ИИС 3. Важные поправки, регламентирующие налоговый режим ИИС 3, до сих пор не приняты. Ограничения касаются как новых ИИС 3, открытых с начала 2024 года, так и ИИС 3, которые были получены путем трансформации открытых ранее ИИС 1 или ИИС 2.'}]
# [{'CHANNEL': 'investoksana', 'POST': 5851, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '15:28', 'NEWS_TEXT': '260$ за январь 2024 начислили процентов на остаток в IB, но пополнять IB стало очень тяжело, хотя с выводом денег в Россию из IB проблем нет. Приходится новые доходы пока складировать на накопительном счёте в Тинькофф под 11%.'}]
# [{'CHANNEL': 'investoksana', 'POST': 5852, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '16:34', 'NEWS_TEXT': 'Минфин сообщил об исполнении бюджета в январе с дефицитом 308 млрд рублей. По оценке ведомства, в прошлом месяце в казну поступили 2 трлн 396 млрд рублей — это на 76,6% больше, чем за аналогичный период 2023 го. Кроме того, в ведомстве сообщили, что нефтегазовые доходы за январь выросли на 58,7% относительно начала 2023 года и составили 675 млрд рублей.'}]
# Канал:
# kapitalopedia
# Подписчиков:
# 33.8K
# Первая новость в корпусе:
# 3101
# Крайняя новость в корпусе:
# 3814
# Крайняя новость в ТГ:
# 3816
# Будет загружено
# 1
# [{'CHANNEL': 'kapitalopedia', 'POST': 3815, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '11:33', 'NEWS_TEXT': 'ТОП 5 дивидендных акций на 2024 Сбербанк SBER SBERP. Дивиденды за 2023 год ожидаются в районе 35 40 рублей за 1 акцию, что может составить 14% дивидендной доходности. Предыдущий год выдался хорошим у Сбера, и показатели сильные по выручке, чистой прибыли, поэтому прогноз по дивидендам вполне может быть утверждён советом директоров. Лукойл LKOH. Дивиденды за 2023 год ожидаются в районе 800 рублей за 1 акцию, что может составить 11% дивидендной доходности. Лукойл платит исправно дивиденды, так что есть тоже все шансы на утверждение дивидендов к выплате. Сургутнефтегаз преф SNGSP. Дивиденды за 2023 год ожидаются в районе 12 13 рублей за 1 акцию, что может составить 22% рекордной дивидендной доходности. Тут всё зависит напрямую от курса доллара, т.к. у компании есть кубышка , 75% которой находится в валюте. Пока рубль крепнет, снижается прибыль и размер дивидендов за счет переоценки валютной кубышки и наоборот. Новабев бывш. Белуга BELU. Совокупные дивиденды за 12 месяцев ожидаются в районе 700 рублей, что составит 12% дивидендной доходности. Проблем у бизнеса тоже не наблюдается, а дивиденды Белуга платит со всей чистой прибыли. Башнефть преф BANEP. Дивиденды за 2023 год ожидаются в районе 272 рублей за 1 акцию, что может составить 12% дивидендной доходности. В прошлом году компании удалось получить рекордную прибыль в том числе на переработке из за кризиса топлива , но повторить результат в 2024 году навряд ли получится. Есть риск, что могут покупать акции под дивиденды для спекуляций и цена не быстро закроет див. гэп падение цены акций на сумму размера дивидендов . польза инвестидеи'}]
# Канал:
# russia_companies
# Подписчиков:
# 28.9K
# Первая новость в корпусе:
# 2901
# Крайняя новость в корпусе:
# 10319
# Крайняя новость в ТГ:
# 10337
# Будет загружено
# 17
# error
# [{'CHANNEL': 'russia_companies', 'POST': 10321, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:07', 'NEWS_TEXT': 'геополитика Такер Карлсон записал видеообращение, в котором анонсировал интервью с Путиным Такер Карлсон заявил, что Илон Маск обещал не блокировать его интервью с Путиным, когда его опубликуют в соцсети Х'}]
# [{'CHANNEL': 'russia_companies', 'POST': 10322, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:12', 'NEWS_TEXT': 'VTBR Крупные банки в России планируют увеличить штат сотрудников на 7 20% в 2024 году Ъ'}]
# [{'CHANNEL': 'russia_companies', 'POST': 10323, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:14', 'NEWS_TEXT': 'YNDX «Яндекс Маркет» запустил собственный бренд компьютерной техники Lunnen'}]
# [{'CHANNEL': 'russia_companies', 'POST': 10324, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME':
 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '17:12', 'NEWS_TEXT': 'YNDX 5.36% Стоимость поездок в приложении Яндекс Go $YNDX в Москве из за снегопада выросла в три раза'}]
# Канал:
# dohod_investment
# Подписчиков:
# 22.6K
# Первая новость в корпусе:
# 1401
# Крайняя новость в корпусе:
# 3317
# Крайняя новость в ТГ:
# 3319
# Будет загружено
# 1
# [{'CHANNEL': 'dohod_investment', 'POST': 3318, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '15:07', 'NEWS_TEXT': 'Хочу с вами обсудить интересную тему Я сейчас наблюдаю за инфляционными данными и для меня важно понимать, когда ЦБ будет готов снижать ставку? Если ответ сжать до пары слов, то я думаю, что в текущих реалиях снижать ставку ни в коем случае нельзя. Пока все факторы говорят за повысить/оставить без изменений. Сейчас я вижу 2 сценария: 1. Положительный — мы увидим к концу года или во 2 половину снижение ставки максимум на 1%, далее «постоим в боковике», чтобы разобраться какой будет эффект. 2. Отрицательный — ставку поднимут, что потянет за собой устойчивый спрос на валюту, безработицу и ЦБ поймет, что не сможет уже контролировать процесс и поднимет до 20%. Что касается нас, обычных инвесторов, то лично я буду закрывать свои спекулятивные позиции ближе к президентским выборам, чтобы спать спокойно. Что думаете, друзья?'}]
# Канал:
# sgcapital
# Подписчиков:
# 21.2K
# Первая новость в корпусе:
# 2001
# Крайняя новость в корпусе:
# 2234
# Крайняя новость в ТГ:
# 2235
# Будет загружено
# 0
# Канал:
# ruforecasts
# Подписчиков:
# 17.9K
# Первая новость в корпусе:
# 708
# Крайняя новость в корпусе:
# 1740
# Крайняя новость в ТГ:
# 1744
# Будет загружено
# 3
# [{'CHANNEL': 'ruforecasts', 'POST': 1741, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:07', 'NEWS_TEXT': 'Инвестидея по акции Лукойл LKOH Целевая цена: 7 900 ₽ 10,3% Дата идеи: 5 февраля 2024 Аналитики: Газпромбанк Инвестиции Узнавайте инвестидеи и прогнозы первыми, оформляйте подписку на бот ruforecasts'}]
# [{'CHANNEL': 'ruforecasts', 'POST': 1742, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '13:07', 'NEWS_TEXT': 'Инвестидея по акции X5 Group FIVE Целевая цена: 4 515 ₽ 88,6% Дата идеи: 24 января 2024 Аналитики: Солид Брокер Узнавайте инвестидеи и прогнозы первыми, оформляйте подписку на бот ruforecasts'}]
# [{'CHANNEL': 'ruforecasts', 'POST': 1743, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '17:07', 'NEWS_TEXT': 'Инвестидея по акции Яндекс YNDX Целевая цена: 4 180 ₽ 27,5% Дата идеи: 30 января 2024 Аналитики: Finam Alert Узнавайте инвестидеи и прогнозы первыми, оформляйте подписку на бот ruforecasts'}]
# Канал:
# anoniminvest
# Подписчиков:
# 14.3K
# Первая новость в корпусе:
# 1501
# Крайняя новость в корпусе:
# 1955
# Крайняя новость в ТГ:
# 1956
# Будет загружено
# 0
# Канал:
# iporobinhood
# Подписчиков:
# 7.99K
# Первая новость в корпусе:
# 1801
# Крайняя новость в корпусе:
# 2228
# Крайняя новость в ТГ:
# 2231
# Будет загружено
# 2
# [{'CHANNEL': 'iporobinhood', 'POST': 2229, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME':
# Канал:
# if_stocks
# Подписчиков:
# 117K
# Первая новость в корпусе:
# 5809
# Крайняя новость в корпусе:
# 6898
# Крайняя новость в ТГ:
# 6902
# Будет загружено
# 3
# [{'CHANNEL': 'if_stocks', 'POST': 6899, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '10:08', 'NEWS_TEXT': 'Рынки утром Диасофт разместится по оценке 40 45 млрд «Яндекс Маркет» запустил собственный бренд компьютерной техники Lunnen Россия в январе увеличила поставки газа в Европу по трубопроводам на 41% к тому же месяцу прошлого года до 2,52 млрд куб. м. Reuters: Российская компания «Новатэк» открывает офис в Китае для сбыта газа в условиях санкций. IF Stocks'}]
# [{'CHANNEL': 'if_stocks', 'POST': 6900, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '11:50', 'NEWS_TEXT': 'DELI: как отреагировал рынок? Каждое IPO на нашем рынке проходит стандартно. Управляющие: выручка мультипликаторы ебитда кэшфлоу капитализация оценка... Анонимные телеграм канальчики: надо срочно брать!!! / дорогое переоцененное фуфло!!! InvestFuture: IPO — это эмоции. Берите... только если бы взяли по такой цене и без IPO : Крепкое, как задний ум, мнение редакции таково: 1. Позитивные эмоции на первом IPO года это однозначный плюс для рынка! 2. В долгосрок каршеринг — интересный бизнес. Но оценка при IPO высоковата. При этом часть позиции можно брать и по предлагаемым уровням. А вот остальное, пожалуй, при первой серьезной коррекции. А коррекция должна быть, особенно после заявлений о том, что за 2023 год дивов не планируется. IF Stocks'}]
# [{'CHANNEL': 'if_stocks', 'POST': 6901, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '13:46', 'NEWS_TEXT': 'GigaChat PRO показала лучшие результаты по итогам теста MERA В рамках теста проверялись 20 Al моделей. Для исследования была разработана система, которая включает 21 задачу в инструктивном формате, замеры ряда популярных открытых моделей для сравнения, кодовую базу, веб сайт с личным кабинетом и системой оценки, а также человеческий бенчмарк — средняя оценка того, как эти же задания выполняют люди. Независимый бенчмарк MERA для оценки фундаментальных моделей для русского языка был разработан на площадке Альянса в сфере искусственного интеллекта исследователями индустрии, а также академическими партнерами Skoltech AI и НИУ ВШЭ. IF Stocks'}]
# Канал:
# lemonfortea
# Подписчиков:
# 157K
# Первая новость в корпусе:
# 879
# Крайняя новость в корпусе:
# 1922
# Крайняя новость в ТГ:
# 1925
# Будет загружено
# 2
# error
# [{'CHANNEL': 'lemonfortea', 'POST': 1924, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '17:26', 'NEWS_TEXT': 'Неужели рост цен в России замедлился? Центробанк увидел тренд на замедление инфляции, — по крайней мере, так написано в свежем исследовании регулятора. Этот тренд стал особенно заметен в декабре 2023 январе 2024. — годовая инфляция в ноябре 2023 составила 7,5%, — в декабре 7,4%, — в январе 7,3%. Замедление наблюдалось во всех укрупненных категориях, но наиболее сильно проявилось в услугах, говорится в исследовании. Всё налаживается? Хотел бы я так думать, но увы. Замедление инфляции — это больше из за временных факторов, а также и укреплением рубля. Даже ЦБ поясняет, что рано радоваться. Более того, ожидания дальнейшего роста цен у бизнес и россиян всё ещё высокие. То есть тренд на замедление инфляции как бы есть, но устойчивый ли он и надолго — пока сомневаюс
второй и третий танкер, зная, что они предназначены для проекта под санкциями, это станет позитивной новостью для НОВАТЭКа БКС Мир инвестиций При текущих мировых ценах на цветные металлы и слабом производственном прогнозе на 2024 г. бумаги «Норникеля» кажутся нам переоцененными. Для возвращения на уровни в 17 18 тыс. руб. за акцию необходим либо уверенный разворот в ценах на никель и палладий, либо новый виток ослабления рубля Велес Капитал Finam Alert это рыночные сигналы, идеи, торговые прогнозы'}]
# Канал:
# bcs_express
# Подписчиков:
# 56.8K
# Первая новость в корпусе:
# 12686
# Крайняя новость в корпусе:
# 16664
# Крайняя новость в ТГ:
# 16676
# Будет загружено
# 11
# [{'CHANNEL': 'bcs_express', 'POST': 16665, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '08:31', 'NEWS_TEXT': 'Медленно, но верно вверх Индекс акций МосБиржи вновь переписал многомесячные максимумы, и на повестке дня — открытый межсессионный гэп середины ноября. Монотонный подъем рынка совершенно не смущает — среднесрочный ориентир вверх значительно выше текущих. Бумаги в фокусе — Мать и дитя, ПИК, Яндекс, Магнит, РУСАЛ. На внешнем контуре индексы акций США остаются в области исторических максимумов, плоская коррекция в S P 500 вскоре может завершиться штурмом 5000 п. В Азии состоялась вторая волна китайского ралли, и на Гонконге можно было поднять уже свыше 6%. Российские активные трейдеры отрабатывают динамику США, Европы, Азии через фьючерсы на Мосбирже. На сырьевом рынке нефть Brent развивает технический отскок от $77, и баррель уже у $79 золото смогло закрепиться выше $2030 на фоне отката индекса доллара DXY, и для унции это не предел роста а вот газ NG все таки рухнул на $2/Mmbtu — ниже только апрельское дно 2023 г. Оцениваем ближайшие перспективы в утреннем материале: https://bcs express.ru/novosti i analitika/prognozy i kommentarii medlenno no verno vverkh'}]
# ...
# Канал:
# profitking
# Подписчиков:
# 24.1K
# Первая новость в корпусе:
# 8203
# Крайняя новость в корпусе:
# 13719
# Крайняя новость в ТГ:
# 13733
# Будет загружено
# 13
# [{'CHANNEL': 'profitking', 'POST': 13720, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '08:18', 'NEWS_TEXT': '\u200b\u200b 1 804,68% Как всегда с утра, отчет по счету ПРОВЕРИТЬ МОЙ СЧЕТ до 12.07 на Comon Это не картинка. А скрин личного кабинета. Все мои сделки в режиме online как всегда в Клубе PROFITKING Продолжение без Common'}]
# error
# error
# error
# [{'CHANNEL': 'profitking', 'POST': 13724, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '10:32', 'NEWS_TEXT': 'Запись утреннего брифа из Клуба ProfitKing'}]
# error
# error
# [{'CHANNEL': 'profitking', 'POST': 13727, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '11:08', 'NEWS_TEXT': 'мысливслух Касательно ситуации с Яндексом. Почему я продал акцию и не буду покупать пока. Все просто. Покупка сейчас акций Яндекса это ставка на то, что от нас не завист. Ставка на удачу. Повезет будут откупать, выкупать, объявят кофф конвертации ура!! Мы выиграли. Не повезет новости будут плохие проиграли. Чистое казино. Мы и так работаем в сфере высокориского бизнеса. Практически каждый из нас торгует определенной вероятностью исхода тех или иных событий. И это зашифровано в нашу торговую систему. Ну там хоть мы ничего не ждем. Трейд пошел держим, двигаем стоп. Не пошел ушли. Тут же нет смысла ставить стопы. Надо просто ждать выхода новостей. Иначе торговать бесполезно. ИМХО И получается я должен взять свои семейные деньги и поставить их просто на удачу. На черное или красное? Я так не играю.'}]
# [{'CHANNEL': 'profitking', 'POST': 13728, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '11:26', 'NEWS_TEXT': 'В Мае 2007 года состоялось народное IPO ВТБ. С каждого угла только и слышали ВТБ ВТБ ВТБ ВТБ ВТБ..... Цена размещения была 13,5 копеек. 20% всех акций выкупили физические лица. Для тех времен это было очень большая часть. Спустя 18 лет акции стоят на 80% дешевле. Они так ни разу даже и близко не вернулись к цене IPO. Акции тогда предлагали всем и бабушкам и дедушкам. Даже я помню, что участвовал небольшим пакетом. В кризис 2008 2009 годов я помню как мы все называли эту акцию ВТБ две копейки.... Нет ничего стабильного и гарантированного на бирже. Нет, не было и не будет. Чет, меня сегодня на лирику понесло. Старею'}]
# [{'CHANNEL': 'profitking', 'POST': 13729, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '12:03', 'NEWS_TEXT': 'Сбербанк возможно неплохой момент для покупки'}]
# error
# [{'CHANNEL': 'profitking', 'POST': 13731, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '13:55', 'NEWS_TEXT': 'Сбербанк за 4 часа торгов прошел средний дневной оборот с начала года Видимо, стоит ждать ускорение движения'}]
# [{'CHANNEL': 'profitking', 'POST': 13732, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '15:10', 'NEWS_TEXT': 'Да, Саш именно для этого. Для того, чтобы уходить по стопу Для того, чтобы понимать что у меня 25 30% убыточных трейдов Для того, чтобы не спорить с рынком Для того , чтобы знать, что на бирже может быть всё, что угодно Для того чтобы моя средняя прибыль была в 3 5 раза больше среднего убытка Для того, чтобы торговать сам для себя Для того чтобы зарабатывать на трейдах по 50 60 70% за неделю Для того чтобы понять слова Ларри, что Это сделка может быть самой убыточной Для того чтобы сомневаться в себе Для того чтобы можно было сказать Вот мой публичный стэйтмент за последние несколько лет, на котором была пандемия, СВО, Мобилизация. Я могу бесконечно долго продолжать. А вам дам дельный совет, абсолютно бесплатно отпишитесь. Удачи.'}]
# Канал:
# bizlike
# Подписчиков:
# 180K
# Первая новость в корпусе:
# 3851
# Крайняя новость в корпусе:
# 5159
# Крайняя новость в ТГ:
# 5163
# Будет загружено
# 3
# [{'CHANNEL': 'bizlike', 'POST': 5160, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '12:56', 'NEWS_TEXT': 'Кто хочет начать инвестировать? А почему не начинаете? Есть страх прогадать, купить не те акции, потерять деньги, да и вообще опыта в этом нет? Тогда получите 50 тыс. рублей от Тинькофф Инвестиций! До 15 марта при открытии брокерского счета инвестор получает от банка 50.000 рублей для покупки акций. Акция действует для новых пользователей. Это шанс не просто погрезить о том, какой вы волк с уолл стрит, а стать им! Может раньше вам не хватало накоплений и дерзости, а сейчас они у вас есть. И есть возможность не возмещать убытки. Так, если вы вложите в акции, а рынок просядет. Не страшно. Просто 1 опыт в копилку. Ну а если окажетесь в прибыли – она ваша! Готовы стать инвестором? Открывайте счет и получайте 50 тыс. рублей для страта! Подробности по этой ссылке. Реклама, АО «Тинькофф Банк», ИНН 7710140679, лицензия ЦБ РФ № 2673, Erid:2SDnjdqybNx'}]
# [{'CHANNEL': 'bizlike', 'POST': 5161, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME':
ПРОМ, Сбербанк, Роснефть, ЛУКОЙЛ, Норникель. Акции с более низкой ликвидностью называют «вторым эшелоном». Самые низколиквидные бумаги, сделки по которым проходят раз в день или реже, называют «акциями третьего эшелона». Зачем бизнесу выпускать акции? Чтобы открывать новые филиалы, запускать проекты и нанимать дорогих специалистов, компании нужны деньги. Можно взять кредит под высокий процент, а можно разместиться на бирже и выпустить акции в обращение. К примеру сейчас брать кредит под 18% или выпустить облигации под 17% очень дорого. Для компании выгоднее разместить акции на бирже. Количество акций всегда строго регулируется. \u200d Короче не полу ...
# Канал:
# spydell_finance
# Подписчиков:
# 105K
# Первая новость в корпусе:
# 2501
# Крайняя новость в корпусе:
# 4950
# Крайняя новость в ТГ:
# 4952
# Будет загружено
# 1
# [{'CHANNEL': 'spydell_finance', 'POST': 4951, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '08:57', 'NEWS_TEXT': 'Если все так замечательно в США, как нам пытаются внушить ньюс мейкеры, официальная макростатистика и рыночный сентимент, почему альтернативные индикаторы бизнес активности остаются на депрессивном уровне? Промышленный индекс ISM на уровне 49.1 последнее значение означает, что индекс находится в зоне сокращения в течение 15 месяцев подряд самая длительная серия сокращения с кризиса 2008 после 29 месячного периода роста, начиная с июня 2020 года. Empire State Manufacturing Индекс общих деловых условий упал на двадцать девять пунктов до 43,7, что является самым низким показателем с мая 2020 года. Новые заказы и отправки также существенно сократились. Dallas Fed Manufacturing. Производственная активность в Техасе сократилась в январе после стабилизации в декабре. Текущее значение является минимальным с апреля 2020 и второе худшее значение в период ужесточения ДКП с марта 2022. Kansas City Fed Manufacturing – резко снизился в январе до минимальных значений за два года, повторяя минимум с июня 2020. Цены на сырье в январе резко выросли по сравнению с прошлым месяцем. Ожидается, что в будущем цены на сырье будут продолжать расти более быстрыми темпами, чем цены на готовую продукцию, что приведет к сокращению маржинальности. Philly Fed Manufacturing Index без признаков улучшения. На протяжении 18 из 20 последних месяцев находится в отрицательной области, повторяя антирекорд 2008 Композитный индекс промышленной активности от региональных представительств ФРС резко обвалился в январе до уровня, на котором ранее всегда происходил кризис, повторяя минимальные значения с ковидного мая 2020. NFIB business optimism Index – индекс настроения малого и среднего бизнеса находится без движения на минимальных уровнях с кризиса 2008 2009. Как то не просматривается сильнейший восстановительный импульс с конца 90 х годов? Реальная производственная экономика в условиях кризиса, по крайней мере, по восприятию менеджеров.'}]
# Канал:
# divForever
# Подписчиков:
# 90.8K
# Первая новость в корпусе:
# 16501
# Крайняя новость в корпусе:
# 20996
# Крайняя новость в ТГ:
# 21009
# Будет загружено
# 12
# [{'CHANNEL': 'divForever', 'POST': 20997, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:17', 'NEWS_TEXT': 'Мосбиржа допустила акции Диасофта к торгам с 15 февраля Читать далее https://smartlab.news/i/105515 DIAS'}]
# [{'CHANNEL': 'divForever', 'POST': 20998, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:18', 'NEWS_TEXT': 'СД Диасофта рекомендовал выплатить дивиденды за II полугодие 2023 года в 75,68 руб. на акцию Читать далее https://smartlab.news/i/105528 DIAS'}]
# [{'CHANNEL': 'divForever', 'POST': 20999, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:18', 'NEWS_TEXT': 'Диапазон цены размещения Диасофт в рамках IPO 4 4,5 тыс. руб/акция, соответствует капитализации 40 45 млрд руб. до допэмиссии Читать далее https://smartlab.news/i/105529 DIAS'}]
# [{'CHANNEL': 'divForever', 'POST': 21000, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '09:21', 'NEWS_TEXT': 'DIAS ipo ДИАПАЗОН ЦЕНЫ РАЗМЕЩЕНИЯ ДИАСОФТ В РАМКАХ IPO 4 4,5 ТЫС. РУБ./АКЦИЯ, СООТВЕТСТВУЕТ КАПИТАЛИЗАЦИИ 40 45 МЛРД РУБ. ДО ДОПЭМИССИИ Базовый размер IPO составит до 800 тысяч Акций, что соответствует 8% от количества выпущенных и находящихся в обращении Акций релиз'}]
# [{'CHANNEL': 'divForever', 'POST': 21001, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '10:10', 'NEWS_TEXT': 'Диасофт рассматривает возможность SPO через 2 года после проведения IPO для привлечения новых инвестиций, необходимых для развития бизнеса — гендиректор компании Читать далее https://smartlab.news/i/105536 DIAS'}]
# [{'CHANNEL': 'divForever', 'POST': 21002, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '10:10', 'NEWS_TEXT': 'Диасофт планирует в 2024 2025гг ежеквартально направлять на выплату дивидендов почти всю получаемую прибыль не менее 80% от EBITDA — гендиректор компании Читать далее https://smartlab.news/i/105537 DIAS'}]
# [{'CHANNEL': 'divForever', 'POST': 21003, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '11:53', 'NEWS_TEXT': 'DELI дивиденд ДЕЛИМОБИЛЬ НЕ БУДЕТ ПЛАТИТЬ ДИВИДЕНДЫ ПО ИТОГАМ ДЕЯТЕЛЬНОСТИ 2023 Г ПРЕДСЕДАТЕЛЬ СОВЕТА ДИРЕКТОРОВ — ТАСС'}]
# [{'CHANNEL': 'divForever', 'POST': 21004, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '13:31', 'NEWS_TEXT': 'МНЕНИЕ: Новатэк может выплатить 45,5 рубля на акцию, дивидендная доходность 3,2% Мир инвестиций Читать далее https://smartlab.news/i/105562 NVTK'}]
# [{'CHANNEL': 'divForever', 'POST': 21005, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '13:31', 'NEWS_TEXT': 'Наша финансовая модель предполагает выплату хотя бы 50% чистой прибыли дивидендов. Если будет возможность выплатить больше Набсовет конечно же рассмотрит — Мосбиржа Читать далее https://smartlab.news/i/105564'}]
# [{'CHANNEL': 'divForever', 'POST': 21006, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '14:40', 'NEWS_TEXT': 'МНЕНИЕ: ВТБ Мои Инвестиции назвали топ 20 дивидендных акций на 2024 год Читать далее https://smartlab.news/i/105581 SNGS'}]
# [{'CHANNEL': 'divForever', 'POST': 21007, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '15:55', 'NEWS_TEXT': 'Банк России 07.02.2024 принял решение о государственной регистрации изменений в решения о выпуске обыкновенных и привилегированных акций, государственные регистрационные номера выпусков 1 01 00206 А и 2 01 00206 А от 08.08.1996, путем регистрации решений о выпуске ценных бумаг, а также о государственной регистрации изменений в решения о дополнительном выпуске обыкновенных акций публичного акционерного общества «Транснефть» г. Москва , государственн id636 micex TRNFP новости'}]
# [{'CHANNEL': 'divForever', 'POST': 21008, 'NEWS_DATE': '07-02-2024', 'NEWS_TIME': '16:09', 'NEWS_TEXT': 'MOEX дивиденд Мосбиржа планирует направлять от 50% прибыли на дивиденды, заявил директор Мосбиржи по связям с инвесторами Антон Терентьев'}]
